# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.decomposition import PCA

# --- Define Paths and Directories ---
# The input path points to your raw data
dataset_path = "../data/raw/Maize"
# The output path will be a new folder for the cleaned data
output_path = "../data/processed/IT24103044_clean"
os.makedirs(output_path, exist_ok=True)

# --- Perform Outlier Removal ---
print("Starting outlier detection and removal...")

# Track stats for EDA
class_valid_counts = {}
class_outlier_counts = {}
brightness_means = []

# Get a list of the class folders
class_folders = [f for f in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, f))]

for class_name in class_folders:
    class_path = os.path.join(dataset_path, class_name)
    output_class_path = os.path.join(output_path, class_name)
    os.makedirs(output_class_path, exist_ok=True)

    valid_count = 0
    outlier_count = 0

    for img_file in os.listdir(class_path):
        # Skip non-image files
        if not img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
            continue

        img_path = os.path.join(class_path, img_file)
        try:
            # Try to load and check the image
            img = cv2.imread(img_path)
            
            # Check 1: If the image is corrupted or invalid
            if img is None:
                print(f"⚠ Outlier removed (corrupted): {img_file}")
                outlier_count += 1
                continue
                
            # Check 2: If the image is too small
            h, w, _ = img.shape
            if h < 50 or w < 50:
                print(f"⚠ Outlier removed (too small): {img_file}")
                outlier_count += 1
                continue

            # Check 3: If the image is too dark or bright
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            mean_brightness = np.mean(gray)
            brightness_means.append(mean_brightness)

            if mean_brightness < 20 or mean_brightness > 235:
                print(f"⚠ Outlier removed (abnormal brightness): {img_file}")
                outlier_count += 1
                continue

            # If all checks pass, save the valid image to the output folder
            cv2.imwrite(os.path.join(output_class_path, img_file), img)
            valid_count += 1

        except Exception as e:
            # Handle any other errors during image reading
            print(f"⚠ Error reading {img_file} in {class_name}: {e}")
            outlier_count += 1

    class_valid_counts[class_name] = valid_count
    class_outlier_counts[class_name] = outlier_count
    print(f"Class '{class_name}': {valid_count} valid, {outlier_count} outliers removed")

print("\n✅ Completed outlier removal.")

# --- EDA Visualizations ---
# 1. Brightness distribution
plt.figure(figsize=(8, 5))
plt.hist(brightness_means, bins=50, color="purple")
plt.title("Brightness Distribution of Valid Images")
plt.xlabel("Mean Brightness (0–255)")
plt.ylabel("Frequency")
plt.show()

# 2. Valid vs Outliers per class
labels = list(class_valid_counts.keys())
valids = list(class_valid_counts.values())
outliers = list(class_outlier_counts.values())

x = np.arange(len(labels))
width = 0.35

plt.figure(figsize=(12, 6))
plt.bar(x - width/2, valids, width, label="Valid", color="green")
plt.bar(x + width/2, outliers, width, label="Outliers", color="red")
plt.xticks(x, labels, rotation=45, ha="right")
plt.ylabel("Image Count")
plt.title("Valid vs Outlier Images per Class")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Starting outlier detection and removal...
# ⚠ Outlier removed (corrupted): leaf beetle90_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle691_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle326_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle798_.jpg
# Corrupt JPEG data: 835 extraneous bytes before marker 0x5e
# Corrupt JPEG data: 29941 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1793 extraneous bytes before marker 0x9e
# ⚠ Outlier removed (corrupted): leaf beetle690_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle208_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle910_.jpg
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 411 extraneous bytes before marker 0xc0
# Corrupt JPEG data: 37 extraneous bytes before marker 0xdb
# ⚠ Outlier removed (corrupted): leaf beetle458_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle573_.jpg
# ⚠ Outlier removed (corrupted): leaf beetle207_.jpg
# Corrupt JPEG data: 8635 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 60 extraneous bytes before marker 0xdb
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 1115 extraneous bytes before marker 0xb4
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Class 'Maize leaf beetle': 938 valid, 10 outliers removed
# Class 'Maize fall armyworm': 285 valid, 0 outliers removed
# ⚠ Outlier removed (corrupted): healthy88_.jpg
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 845 extraneous bytes before marker 0x8a
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (corrupted): healthy18_.jpg
# Class 'Maize healthy': 206 valid, 2 outliers removed
# Class 'Maize grasshoper': 673 valid, 0 outliers removed
# ⚠ Outlier removed (corrupted): leaf blight590_.jpg
# ⚠ Outlier removed (corrupted): leaf blight37_.jpg
# ⚠ Outlier removed (corrupted): leaf blight98_.jpg
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 28240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 69 extraneous bytes before marker 0xdb
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 26519 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 31005 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (corrupted): leaf blight913_.jpg
# ⚠ Outlier removed (corrupted): leaf blight830_.jpg
# ⚠ Outlier removed (corrupted): leaf blight667_.jpg
# ⚠ Outlier removed (corrupted): leaf blight453_.jpg
# Corrupt JPEG data: 27073 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (corrupted): leaf blight746_.jpg
# Corrupt JPEG data: premature end of data segment
# Class 'Maize leaf blight': 998 valid, 8 outliers removed
# ⚠ Outlier removed (corrupted): streak virus422_.jpg
# Corrupt JPEG data: 23 extraneous bytes before marker 0x55
# ⚠ Outlier removed (corrupted): streak virus998_.jpg
# ⚠ Outlier removed (corrupted): streak virus486_.jpg
# ⚠ Outlier removed (corrupted): streak virus701_.jpg
# Corrupt JPEG data: 37 extraneous bytes before marker 0xdb
# Corrupt JPEG data: 50973 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 283 extraneous bytes before marker 0x0c
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (abnormal brightness): streak virus780_.jpg
# ⚠ Outlier removed (corrupted): streak virus627_.jpg
# ⚠ Outlier removed (corrupted): streak virus774_.jpg
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Premature end of JPEG file
# Corrupt JPEG data: 226 extraneous bytes before marker 0x3e
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 181 extraneous bytes before marker 0x24
# Corrupt JPEG data: 52331 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 45904 extraneous bytes before marker 0xd9
# ⚠ Outlier removed (corrupted): streak virus119_.jpg
# Class 'Maize streak virus': 971 valid, 8 outliers removed
# ⚠ Outlier removed (corrupted): leaf spot272_.jpg
# ⚠ Outlier removed (corrupted): leaf spot497_.jpg
# ⚠ Outlier removed (corrupted): leaf spot64_.jpg
# Corrupt JPEG data: 45407 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 425 extraneous bytes before marker 0x21
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 1913 extraneous bytes before marker 0x92
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (corrupted): leaf spot425_.jpg
# ⚠ Outlier removed (corrupted): leaf spot799_.jpg
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 29224 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (corrupted): leaf spot958_.jpg
# ⚠ Outlier removed (corrupted): leaf spot187_.jpg
# ⚠ Outlier removed (corrupted): leaf spot353_.jpg
# ⚠ Outlier removed (corrupted): leaf spot724_.jpg
# Corrupt JPEG data: 592 extraneous bytes before marker 0xdb
# Corrupt JPEG data: 177 extraneous bytes before marker 0x65
# Corrupt JPEG data: 27173 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# ⚠ Outlier removed (corrupted): leaf spot882_.jpg
# Class 'Maize leaf spot': 1249 valid, 10 outliers removed
#
# ✅ Completed outlier removal.
